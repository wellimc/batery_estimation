# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout


df = pd.read_csv('BatteryLog_360.csv',parse_dates=True)
df.set_index(['Date', 'model','screen','video_quality','max_battery','bright'])
df.head()
df.sort_index(inplace= True)
df.plot(figsize=(12,6))
data = lambda data: datetime.datetime.strptime(df[Date], '%d/%m/%Y %H:%M:%S').timestamp()
data = pd.get_dummies(df, columns=['model','screen','video_quality','max_battery','bright'], drop_first=True)

data['Date'] = pd.to_numeric(pd.to_datetime(data['Date']))
print(data)
#training_set = data.iloc[:,:].values
#print(training_set)
# Out:
#                    Date  level  model_J5  screen_5.8  max_battery_3000
# 0   1648490520000000000     68         1           0                 1
# 1   1648491000000000000     67         1           0                 1
# 2   1648491360000000000     66         1           0                 1
# 3   1648491780000000000     65         1           0                 1
# 4   1648492140000000000     64         1           0                 1
# 5   1648492620000000000     63         1           0                 1
# 6   1648493040000000000     62         1           0                 1
# 7   1648493520000000000     61         1           0                 1
# 8   1648493940000000000     60         1           0                 1
# 9   1648494600000000000     59         1           0                 1
# 10  1648495320000000000     58         1           0                 1
# 11  1648495920000000000     57         1           0                 1
# ...

# %%
# Out:
# [0.38888889 0.         0.         1.         0.        ]
# []
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [98], in <cell line: 20>()
#      17 print(x_train.shape[1])
#      19 model = Sequential()
# ---> 20 model.add(LSTM(units = 128, return_sequences=True,input_shape = (x_train.shape[1],1)))
#      21 model.add(Dropout(0.2))
#      22 model.add(LSTM(units = 64, return_sequences=True))
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py:629, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     627 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     628 try:
# --> 629   result = method(self, *args, **kwargs)
#     630 finally:
#     631   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ...
